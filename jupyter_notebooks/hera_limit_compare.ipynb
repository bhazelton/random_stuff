# %%
import eor_limits
from matplotlib import pyplot as plt

# %%
papers = ["li_2019", "trott_2020", "mertens_2020", "hera_2022"]
linewidths = {"li_2019": 1, "trott_2020": 1, "hera_2022": 4}
paper_redshifts = {"trott_2020": [6.5, 7.8], "li_2019": [6.5]}
plot_as_points = ["li_2019", "mertens_2020"]
bold_papers = ["hera_2022"]

# %%
eor_limits.make_plot(
    papers=papers,
    plot_as_points=plot_as_points,
    paper_redshifts=paper_redshifts,
    bold_papers=bold_papers,
    linewidths=linewidths,
    fontsize=20,
    k_range=[0.07, 1]
)
plt.savefig('/Users/bryna/Desktop/hera_limit_compare.pdf')
