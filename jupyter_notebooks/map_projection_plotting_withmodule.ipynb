# %%
# %matplotlib inline
from plotstokesQ_U import plotstokesQ_U

# %%
filepath = '/Volumes/Data1/mwa_healpix/diffuse_survey_4pol/'
obsid_list = [1130781304, 1130789944, 1131454296]
obsid = obsid_list[1]
q_file = filepath + str(obsid) + '_uniform_Residual_Q_HEALPix.fits'
u_file = filepath + str(obsid) + '_uniform_Residual_U_HEALPix.fits'

# %%
plotstokesQ_U(q_file, u_file, projection='mill')
# Out:
# ('RA min, max, mean: ', 101.23743016759776, 130.85658482142856, 116.04737996326047)
# ('Dec min, max, mean: ', -57.209082664567234, -37.215725445986862, -46.978280420725788)
# mill projection
# (array([-0.00386365, -0.00598722, -0.00768241, ..., -0.00223769,
#         -0.00209688,  0.01539917], dtype=float32),
#  array([ 0.00715401,  0.00841581,  0.00712178, ...,  0.00249524,
#          0.00282833,  0.00259898], dtype=float32))
