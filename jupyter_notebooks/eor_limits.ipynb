# %%
import eor_limits
from matplotlib import pyplot as plt

# %%
bold_papers = ["li_2019", "trott_2020", "barry_2019", "hera_2021"]
plot_as_points=["patil_2017", "mertens_2020"]

# %%
theory_params = {
    "mesinger_2016_faint_nf0.8": {
        "paper": "mesinger_2016",
        "model": "faint",
        "nf": 0.8,
        "linewidth": 2,
    },
    "mesinger_2016_bright_nf0.8": {
        "paper": "mesinger_2016",
        "model": "bright",
        "nf": 0.8,
        "linewidth": 2,
    },
    "mesinger_2016_faint_nf0.5": {
        "paper": "mesinger_2016",
        "model": "faint",
        "nf": 0.5,
        "linewidth": 3,
    },
    "mesinger_2016_bright_nf0.5": {
        "paper": "mesinger_2016",
        "model": "bright",
        "nf": 0.5,
        "linewidth": 3
    },
    "pagano_beta1_z8.5": {
        "paper": "pagano_liu_2020",
        "beta": 1,
        "redshift": 8.5,
        "linewidth": 2
    },
    "pagano_beta-1_z8.5": {
        "paper": "pagano_liu_2020",
        "beta": -1,
        "redshift": 8.5,
        "linewidth": 3
    },
}

# %%
eor_limits.make_plot(
    theory_params=theory_params,
    bold_papers=bold_papers,
    plot_as_points=plot_as_points,
    theory_legend=False,
    fontsize=20
)
plt.savefig('/Users/bryna/Projects/Physics/eor_limits/eor_limits.pdf')
