# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors

# %%
paciga_2013 = {
    'telescope': 'GMRT',
    'author': 'Paciga',
    'year': 2013,
    'doi': '10.1093/mnras/stt753',
    'type': 'point',
    'delta_squared': [6.15E4],
    'k': [.5],
    'redshift': [8.6],
    'marker': 'D', #diamond
    'bold': False
}

dillon_2014 = {
    'telescope': 'MWA 32T',
    'author': 'Dillon',
    'year': 2014,
    'doi': '10.1103/PhysRevD.89.023002',
    'type': 'point',
    'delta_squared': [2.6E7, 1.16E6, 8.64E5, 6.7E5, 1.3E6, 1.28E7, 5.26E7, 5.67E8, 4.58E6, 2.93E8, 6.92E8],
    'k': [.058, .06, .063, .065, .0678, .0712, .0715, .149, .15, .15, .089],
    'redshift': [11.68, 10.868, 10.153, 9.518, 8.444, 7.985, 7.57, 7.1896, 6.84, 6.52, 6.23],
    'marker': '^', #TRIANGLE_UP
    'bold': False

}

dillon_2015 = {
    'telescope': 'MWA phase I',
    'author': 'Dillon',
    'year': 2015,
    'doi': '10.1103/PhysRevD.91.123011',
    'type': 'point',
    'delta_squared': [3.8E4, 3.69E4, 4.67E4],
    'k': [.18, .18, .16],
    'redshift': [6.4, 6.8, 7.25],
    'marker': 'v', #TRIANGLE_DOWN
    'bold': False

}

beardsley_2016 = {
    'telescope': 'MWA phase I',
    'author': 'Beardsley',
    'year': 2016,
    'doi': '10.3847/1538-4357/833/1/102',
    'type': 'point',
    'delta_squared': [3.67E4, 2.70E4, 3.56E4, 3.02E4, 4.70E4, 3.22E4, 3.2E4, 2.6E4, 2.5E4],
    'k': [.231, .27, .24, .24, .20, .24, .16, .14, .14],
    'redshift': [7.1, 7.1, 6.8, 6.8, 6.5, 6.5, 7.1, 6.8, 6.5],
    'marker': 'P', # filled plus
    'bold': True
}

patil_2017 = {
    'telescope': 'LOFAR',
    'author': 'Patil',
    'year': 2017,
    'doi': '10.3847/1538-4357/aa63e7',
    'type': 'point',
    'delta_squared': [131.5**2., 242.1**2., 220.9**2., 337.4**2.,
                      407.7**2., 86.4**2., 144.2**2., 184.7**2.,
                      296.1**2., 342.0**2., 79.6**2., 108.8**2.,
                      148.6**2., 224.0**2., 366.1**2.],
    'k': [.053, .067, .083, .103, .128, .053, .067, .083, .103,
          .128, .053, .067, .083, .103, .128],
    'redshift': [8.3, 8.3, 8.3, 8.3, 8.3, 9.15, 9.15, 9.15, 9.15,
                 9.15, 10.1, 10.1, 10.1, 10.1, 10.1],
    'marker': 'o', #CIRCLE
    'bold': False

}

kolopanis_2019 = {
    'telescope': 'PAPER',
    'author': 'Kolopanis',
    'year': 2019,
    'doi': '10.3847/1538-4357/ab3e3a',
    'type': 'point',
    'delta_squared': [8.09e4, 1.28e5, 3.61e4, 1.46e5, 3.8e6, 2.41e6],
    'k': [0.39, 0.53, 0.31, 0.36, 0.334, 0.33],
    'redshift': [7.49, 8.13, 8.37, 8.68, 9.93, 10.88],
    'marker': 's', #SQUARE
    'bold': False

}

barry_2019 = {
    'telescope': 'MWA phase I',
    'author': 'Barry',
    'year': 2019,
    'doi': '10.3847/1538-4357/ab40a8',
    'type': 'line',
    'delta_squared': [np.NaN, 9.22E3, 3.89E3, 6.32E3, 9.61E3, 1.56E4, 2.07E4,
                      8.32E4, np.NaN, np.NaN, 7.09E4, 3.2E4, 4.43E4, 6.38E4,
           1.071, 1.108, 1.145, 1.182, 1.219, 1.256, 1.403, 1.440, 1.477,
           1.514, 1.551, 1.588, 1.625, 1.662]],
    'redshift': [[7.1], [6.8], [6.5]],
    'linewidth': 2.0,
    'bold': True
}


paper_list = [paciga_2013, dillon_2014, dillon_2015, beardsley_2016, patil_2017,
              kolopanis_2019, barry_2019, li_2019]

# %%
max_delta_squared = 1e6
min_delta_squared = 1e3

# %%
redshift_list = []
for paper in paper_list:
    if paper['type'] == 'point':
        inds_use = np.nonzero(np.array(paper['delta_squared']) <= max_delta_squared)
        
        redshift_list += list(np.array(paper['redshift'])[inds_use])
    else:
        for ind, elem in enumerate(paper['redshift']):
            if np.any(np.array(paper['delta_squared'][ind]) <= max_delta_squared):
                redshift_list += elem
redshift_list = sorted(list(set(redshift_list)))
print(redshift_list)
# Out:
# [6.4, 6.5, 6.8, 7.1, 7.25, 7.49, 8.13, 8.3, 8.37, 8.6, 8.68, 9.15, 9.518, 10.1, 10.153]
# /Users/bryna/opt/anaconda3/envs/rasg/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in less_equal
#   if __name__ == '__main__':

# %%
colormap = 'Spectral_r'
# pyplot.set_cmap(colormap)
norm = colors.Normalize(vmin=redshift_list[0],vmax=redshift_list[-1])
scalarMap = cmx.ScalarMappable(norm=norm, cmap=colormap)

# %%
fig = plt.figure(figsize=(20,10))
legend_names = []
lines = []
for paper_i, paper in enumerate(paper_list):
    if paper['bold']:
        label_start = ' $\\bf{'
    else:
        label_start = ' $\\rm{'
    label_end = '}$'
    label = (label_start + '\ '.join(paper['telescope'].split(' '))
             + '\ (' + paper['author'] + ',\ '
             + str(paper['year']) + ')' + label_end)
    legend_names.append(label)
    if paper['type'] == 'point':
        line = plt.scatter(paper['k'], paper['delta_squared'], marker=paper['marker'],
                           c=paper['redshift'], cmap=colormap, norm=norm,
                           edgecolors='black', label=label, s=150, zorder=10)
        lines.append(line)
    else:
        if not isinstance(paper['k'][0], list):
            redshifts = [paper['redshift'][0]]
            k_vals = [paper['k']]
            delta_squared = [paper['delta_squared']]
        else:
            redshifts = list(np.squeeze(paper['redshift']))
            k_vals = paper['k']
            delta_squared = paper['delta_squared']
            
        for ind, redshift in enumerate(redshifts):
            color_val = scalarMap.to_rgba(redshift)

            # make black outline by plotting thicker black line first
            plt.step(k_vals[ind], delta_squared[ind], c='black',
                      linewidth=paper['linewidth']+2, zorder=0)

            line, = plt.step(k_vals[ind], delta_squared[ind],
                            c=color_val, linewidth=paper['linewidth'],
                            label=label, zorder=0)
            if ind == 0:
                lines.append(line)

label_font_size = 22
plt.rcParams.update({'font.size': 15})
plt.xlabel('k ($h Mpc^{-1}$)', fontsize=label_font_size)
plt.ylabel('$\Delta^2$ ($mK^2$)', fontsize=label_font_size)
plt.yscale('log')
plt.xscale('log')
plt.ylim(min_delta_squared, max_delta_squared)
cb = plt.colorbar(fraction=.1, pad=0.08, label='Redshift')
cb.ax.yaxis.set_label_position('left')
cb.ax.yaxis.set_ticks_position('left')
cb.set_label(label='Redshift', fontsize=label_font_size)
plt.grid(axis='y')

leg = plt.legend(lines, legend_names,
                 bbox_to_anchor=(0.75,0),
                 loc="lower right", 
                 bbox_transform=fig.transFigure, ncol=3,
                 frameon=False)

for ind in range(len(paper_list)):
    leg.legendHandles[ind].set_color('gray')
plt.subplots_adjust(bottom=0.25)
plt.savefig('limit_compare.pdf')
